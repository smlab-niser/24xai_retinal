# %%
dn = [0.292, 0.359, 0.1111, 0, 0.0979, 0.1338, 0.0777, 0, 0.0709, 0.375, 0.8889, 0.0325, 0.0467, 0.0467, 0.029, 0, 0.6667, 1, 0.0467, 0.2452, 0.0811]
stle = [0.7765, 0.8108, 0.6667, 0.557, 0.6667, 0.6866, 0.5128, 0.8571, 0.8421, 0.125, 0.8571, 0.6667, 0.75, 0.6857, 0.3902, 0.6957, 0.5714, 1, 0.2353, 0.5576, 1]
itle = [0.7955, 0.8178, 0.5814, 0.6733, 0.5926, 0.7222, 0.6047, 0.8125, 0.8421, 0.1429, 0.8889, 0.6, 0.6, 0.75, 0.4706, 0.6667, 0.75, 0.3077, 0.2, 0.5203, 0.9778]
ctran = [0.7368, 0.4615, 0.5278, 0.544, 0.1514, 0.186, 0.1754, 0.4889, 0.6, 0.2424, 0.7692, 0.6667, 0.3509, 0.5263, 0.7143, 0.1818, 0.2051, 1, 0.2308, 0.4615, 0.9048]
ievit_up = [0.8462, 0.8446, 0.623, 0.6792, 0.6333, 0.6316, 0.6512, 0.8308, 0.7368, 0.32, 0.8889, 0.6667, 0.75, 0.6923, 0.5, 0.6667, 0.5333, 1, 0.2353, 0.6069, 1]
iece = [0.8092, 0.827, 0.6038, 0.6897, 0.5556, 0.6667, 0.5079, 0.7797, 0.85, 0.1429, 0.8, 0.7273, 0.6, 0.7692, 0.6667, 0.7826, 0.8, 1, 0.125, 0.5312, 0.9787]
ieec = [0.7816, 0.8, 0.5526, 0.6869, 0.4792, 0.6389, 0.4878, 0.8214, 0.75, 0.381, 0.8889, 0.6667, 0.7826, 0.8, 0.6667, 0.6957, 0.5714, 1, 0.2857, 0.6081, 0.9048]

# %%
dn2 = [0.8705, 0.8789, 0.5, 0.5, 0.5, 0.816, 0.7416, 0.5, 0.5, 0.6486, 0.9987, 0.8303, 0.5, 0.5, 0.8706, 0.5, 0.7981, 0.4944, 0.5, 0.5, 0.9783]
stle2 = [0.9734, 0.9657, 0.9419, 0.9444, 0.9525, 0.9544, 0.9087, 0.9953, 0.9594, 0.8595, 0.9986, 0.9915, 0.9771, 0.9912, 0.9874, 0.9951, 0.9878, 0.9519, 0.8612, 0.8675, 1]
itle2 = [0.9525, 0.9637, 0.9085, 0.9552, 0.952, 0.9268, 0.8905, 0.9953, 0.976, 0.7804, 0.9986, 0.9772, 0.9799, 0.9552, 0.9904, 0.9966, 0.9273, 0.7657, 0.752, 0.8649, 0.9999]
ctran2 = [0.94, 0.9557, 0.921, 0.8773, 0.9464, 0.8669, 0.9171, 0.98, 0.8896, 0.8389, 0.997, 0.8775, 0.9203, 0.8982, 0.9921, 0.853, 0.9165, 0.825, 0.7466, 0.779, 1]
ievit_up2 = [0.9744, 0.9689, 0.9468, 0.9476, 0.9716, 0.9458, 0.9045, 0.9944, 0.9655, 0.8349, 0.9981, 0.9973, 0.9865, 0.9854, 0.9841, 0.9959, 0.9707, 0.8602, 0.71, 0.8687, 1]
iece2 = [0.9684, 0.9732, 0.908, 0.9333, 0.967, 0.9295, 0.9021, 0.9869, 0.992, 0.8015, 0.9989, 0.9869, 0.9704, 0.9736, 0.966, 0.9991, 0.941, 0.9236, 0.8128, 0.8708, 1]
ieec2 = [0.9605, 0.9552, 0.9209, 0.9203, 0.9413, 0.9486, 0.8936, 0.978, 0.9204, 0.9025, 0.9975, 0.99, 0.9364, 0.9454, 0.9886, 0.9871, 0.9822, 0.8801, 0.7666, 0.8176, 0.9998]

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
labels_list = ['DR', 'NORMAL', 'MH', 'ODC', 'TSLN', 'ARMD', 'DN', 'MYA', 'BRVO', 'ODP', 'CRVO', 'CNV', 'RS', 'ODE', 'LS', 'CSR', 'HTR', 'ASR', 'CRS', 'OTHER', 'RB']
num_vars = len(labels_list)

scores = np.array([dn2, ctran2, stle2, itle2, ievit_up2, iece2, ieec2])
angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist() # Compute angle of each axis

scores = np.concatenate((scores, scores[:, [0]]), axis=1)
angles += angles[:1]

fig, ax = plt.subplots(figsize=(8, 6), subplot_kw=dict(polar=True))

colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k']
# colors = ['tab:blue', 'tab:green', 'tab:red', 'tab:cyan', 'tab:purple', 'tab:orange', 'tab:brown']
for i, (label, score, color) in enumerate(zip(['CNN', 'C-Tran', 'STLE', 'ITLE', 'IEViT-UP', 'IECE', 'IEEC'], scores, colors)):
    ax.plot(angles, score, label=label, color=color)
    ax.fill(angles, score, color=color, alpha=0.05)

ax.set_yticklabels([])
ax.set_xticks(angles[:-1])
ax.set_xticklabels(labels_list)

plt.title('Class-wise AUC scores vs model chart')
plt.legend(loc='upper right', bbox_to_anchor=(1.25, 1.1))
plt.show()

# %%
labels_list = ['DR', 'NORMAL', 'MH', 'ODC', 'TSLN', 'ARMD', 'DN', 'MYA', 'BRVO', 'ODP', 'CRVO', 'CNV', 'RS', 'ODE', 'LS', 'CSR', 'HTR', 'ASR', 'CRS', 'OTHER', 'RB']
x = np.arange(len(labels_list))
fig, ax = plt.subplots(figsize=(8, 4))

ax.plot(x, dn, label='CNN', color='b')
ax.plot(x, ctran, label='C-Tran', color='g')
ax.plot(x, stle, label='STLE', color='r')
ax.plot(x, itle, label='ITLE', color='c')
ax.plot(x, ievit_up, label='IEViT-UP', color='m')
ax.plot(x, iece, label='IECE', color='y')
ax.plot(x, ieec, label='IEEC', color='k')

ax.set_xlabel('Labels')
ax.set_ylabel('F1 Scores')
ax.set_title('Class-wise F1 scores vs model')
ax.set_xticks(x)
ax.set_xticklabels(labels_list, rotation=90)

plt.legend(loc='upper right', bbox_to_anchor=(1.2, 1.1))
plt.grid()
plt.tight_layout()
plt.show()
